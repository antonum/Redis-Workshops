# %% [markdown]
# <a href="https://colab.research.google.com/github/antonum/Redis-Workshops/blob/experimental/Google-GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade --quiet  langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 3.7 MB/s eta 0:00:00

# %% [markdown]
# https://python.langchain.com/docs/integrations/chat/google_generative_ai/
#
# Get Google API key at https://console.cloud.google.com/apis/credentials

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Provide your Google API Key")
# Out:
# Provide your Google API Key··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("Write a ballad about LangChain")
print(result.content)
# Out:
# In realms of code, where knowledge flows,
# A tale unfolds, of LangChain's prose.
# A language born, a child of might,
# To guide our thoughts, and shed new light.
#
# With every line, a symphony of grace,
# LangChain weaves magic, leaving not a trace.
# Its syntax clear, a beacon in the night,
# Guiding us forward, with celestial light.
#
# From humble roots, a sapling takes its stand,
# LangChain's branches reach across the land.
# Developers gather, eager to embrace,
# Its power and potential, to chase.
#
# In algorithms, it finds its true delight,
# Unveiling patterns, hidden from our sight.
# Natural language, its domain so vast,
# A bridge between machines and minds surpassed.
#
# Its versatility, a treasure to behold,
# From AI models to stories yet untold.
# LangChain empowers, breaks down every wall,
# A tool for dreamers, standing tall.
#
# Like a river, flowing through our veins,
# LangChain connects us, breaks down the chains.
# A community united, hand in hand,
# Building a future, on LangChain's grandstand.
#
# So let us sing, of this language so fine,
# LangChain, the beacon, guiding our design.
# In its embrace, let our imaginations soar,
# And together, create wonders we adore.
