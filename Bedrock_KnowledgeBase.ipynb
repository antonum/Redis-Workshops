# %% [markdown]
# <a href="https://colab.research.google.com/github/antonum/Redis-Workshops/blob/experimental/Bedrock_KnowledgeBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q boto3
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 11.1 MB/s eta 0:00:00

# %%
aws_access_key_id="AKIAY3LZEREXAMPLE" # @param {type:"string"}
aws_secret_access_key='XXXXX' # @param {type:"string"}
region_name='us-east-1' # @param {type:"string"}

# %%
import boto3
bedrock_agent_runtime = boto3.client(service_name='bedrock-agent-runtime',aws_access_key_id=aws_access_key_id,aws_secret_access_key=aws_secret_access_key,region_name=region_name)

# %%
def retrieveAndGenerate(input, kbId):
    return bedrock_agent_runtime.retrieve_and_generate(
        input={
            'text': input
        },
        retrieveAndGenerateConfiguration={
            'type': 'KNOWLEDGE_BASE',
            'knowledgeBaseConfiguration': {
                'knowledgeBaseId': kbId,
                'modelArn': 'arn:aws:bedrock:us-east-1::foundation-model/anthropic.claude-instant-v1'
                }
            }
        )

response = retrieveAndGenerate("Summarize the story for me in 2 sentences", "FBYN0KZEFQ")
response["output"]["text"]
# Out:
# 'Alice has a dream where she attends a strange trial and encounters the Queen of Hearts who tries to have her beheaded. A creature tells the story of how he was created and brought to life but then became a murderer.'
